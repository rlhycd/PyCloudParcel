# %%
import pint, numpy as np
si = pint.UnitRegistry()

# %% [markdown]
# # Sim 1

# %%
class setup:
    figname_profiles = 'pics/sim1_profiles.pdf'
    figname_radii = 'pics/sim1_radii.pdf'
    q0 = 21.5 * si.grams / si.kilogram
    w = 10 * si.metre / si.second
    t = 50 * si.seconds
    rd = [np.array([235]) * si.nanometre, np.array([120,  350]) * si.nanometre] 
    nd = [np.array([100]) / si.milligram, np.array([50, 50]) / si.milligram]
    dt_max = .1 * si.second
    S_min, S_max = .99-1, 1.025-1

# %%
# %run "Activ_Deactiv.ipynb"
# Out:
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# 674.0727685678578 nanometer
# 341.07858436574617 nanometer
# 1007.1058623179243 nanometer
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# 1.0102135872294724e-07 gram * liter / kilogram / meter ** 2 / nanometer
# 2.7684685297224613e-07 gram * liter / kilogram / meter ** 2 / nanometer
# 5.557882916801557e-08 gram * liter / kilogram / meter ** 2 / nanometer
# <img src="data:image/png;base64,..." width="1000">
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# ---------------------------------------------------------------------------
# DimensionalityError                       Traceback (most recent call last)
# /home/michael/Documents/clones/ripening/Activ_Deactiv.ipynb in <module>()
#       4         y = t[0]
#       5         x = np.empty_like(dr_dt[0][0]) * dr_dt[0].units
# ----> 6         x.magnitude[:] = ph.mgn(np.interp(y, t[i], dr_dt[i][j]), dr_dt[0].units)
#       7         ax1.plot(x, y, label=sim[i], lw = lw(i),color = color(i,j))
#       8         ax2.plot(x - dr_dt[0][0], y,  lw = lw(i),color = color(i,j))
#
# /home/michael/Documents/clones/ripening/Activ_Deactiv.ipynb in mgn(self, q, u)
#      38
#      39     def mgn(self, q, u):
# ---> 40         return (q/u).to(self.si.dimensionless).magnitude
#      41
#      42     def dp_dt(self, p, T, w, q):
#
# /usr/lib/python3/dist-packages/pint/quantity.py in to(self, other, *contexts, **ctx_kwargs)
#     373         other = to_units_container(other, self._REGISTRY)
#     374
# --> 375         magnitude = self._convert_magnitude_not_inplace(other, *contexts, **ctx_kwargs)
#     376
#     377         return self.__class__(magnitude, other)
#
# /usr/lib/python3/dist-packages/pint/quantity.py in _convert_magnitude_not_inplace(self, other, *contexts, **ctx_kwargs)
#     341                 return self._REGISTRY.convert(self._magnitude, self._units, other)
#     342
# --> 343         return self._REGISTRY.convert(self._magnitude, self._units, other)
#     344
#     345     def _convert_magnitude(self, other, *contexts, **ctx_kwargs):
#
# /usr/lib/python3/dist-packages/pint/registry.py in convert(self, value, src, dst, inplace)
#     709             return value
#     710
# --> 711         return self._convert(value, src, dst, inplace)
#     712
#     713     def _convert(self, value, src, dst, inplace=False, check_dimensionality=True):
#
# /usr/lib/python3/dist-packages/pint/registry.py in _convert(self, value, src, dst, inplace)
#    1240                 value, src = src._magnitude, src._units
#    1241
# -> 1242         return super(ContextRegistry, self)._convert(value, src, dst, inplace)
#    1243
#    1244     def _get_compatible_units(self, input_units, group_or_system):
#
# /usr/lib/python3/dist-packages/pint/registry.py in _convert(self, value, src, dst, inplace)
#     993
#     994         if not (src_offset_unit or dst_offset_unit):
# --> 995             return super(NonMultiplicativeRegistry, self)._convert(value, src, dst, inplace)
#     996
#     997         src_dim = self._get_dimensionality(src)
#
# /usr/lib/python3/dist-packages/pint/registry.py in _convert(self, value, src, dst, inplace, check_dimensionality)
#     731             # then the conversion cannot be performed.
#     732             if src_dim != dst_dim:
# --> 733                 raise DimensionalityError(src, dst, src_dim, dst_dim)
#     734
#     735         # Here src and dst have only multiplicative units left. Thus we can
#
# DimensionalityError: Cannot convert from 'second / meter' ([time] / [length]) to 'dimensionless' (dimensionless)

# %% [markdown]
# # Sim 2

# %%
class setup:
    figname_profiles = 'pics/sim2_profiles.pdf'
    figname_radii = 'pics/sim2_radii.pdf'
    q0 = 21.5 * si.grams / si.kilogram
    w = .08 * si.metre / si.second
    t = 5000 * si.seconds
    rd = [np.array([235]) * si.nanometre, np.array([120,  350]) * si.nanometre] 
    nd = [np.array([100]) / si.milligram, np.array([50, 50]) / si.milligram]
    dt_max = 1 * si.second
    S_min, S_max = .9999-1, 1.0005-1

# %%
# %run "Activ_Deactiv.ipynb"
# Out:
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# 787.1955830790321 nanometer
# 396.9885739176378 nanometer
# 1177.4870129438195 nanometer
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# 1.0074160498726463e-07 gram * liter / kilogram / meter ** 2 / nanometer
# 2.760821300829255e-07 gram * liter / kilogram / meter ** 2 / nanometer
# 5.5425306011186764e-08 gram * liter / kilogram / meter ** 2 / nanometer
# <img src="data:image/png;base64,..." width="1000">
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
