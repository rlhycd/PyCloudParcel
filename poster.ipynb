# %%
import pint, numpy as np
si = pint.UnitRegistry()

# %% [markdown]
# # Sim 1

# %%
class setup:
    figname_profiles = 'pics/sim1_profiles.pdf'
    figname_radii = 'pics/sim1_radii.pdf'
    q0 = 21.5 * si.grams / si.kilogram
    w = 10 * si.metre / si.second
    t = 50 * si.seconds
    rd = [np.array([235]) * si.nanometre, np.array([120,  350]) * si.nanometre] 
    nd = [np.array([100]) / si.milligram, np.array([50, 50]) / si.milligram]
    dt_max = .1 * si.second
    S_min, S_max = .99-1, 1.025-1

# %%
# %run "Activ_Deactiv.ipynb"
# Out:
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# 787.1955830790321 nanometer
# 396.9885739176378 nanometer
# 1177.4870129438195 nanometer
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/slayoo/devel/ripening/Activ_Deactiv.ipynb in <module>()
#      14 plt.show()
#      15
# ---> 16 plt.savefig(setup.figname_radii)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2556             file = filename._file
#    2557         else:
# -> 2558             file = PdfFile(filename, metadata=metadata)
#    2559         try:
#    2560             file.newPage(width, height)
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     431         self.original_file_like = None
#     432         self.tell_base = 0
# --> 433         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     434         if not opened:
#     435             try:
#
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     390             fh = bz2.BZ2File(fname, flag)
#     391         else:
# --> 392             fh = open(fname, flag, encoding=encoding)
#     393         opened = True
#     394     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pics/sim1_radii.pdf'

# %% [markdown]
# # Sim 2

# %%
class setup:
    figname_profiles = 'pics/sim2_profiles.pdf'
    figname_radii = 'pics/sim2_radii.pdf'
    q0 = 21.5 * si.grams / si.kilogram
    w = .08 * si.metre / si.second
    t = 5000 * si.seconds
    rd = [np.array([235]) * si.nanometre, np.array([120,  350]) * si.nanometre] 
    nd = [np.array([100]) / si.milligram, np.array([50, 50]) / si.milligram]
    dt_max = 1 * si.second
    S_min, S_max = .9999-1, 1.0005-1

# %%
# %run "Activ_Deactiv.ipynb"
# Out:
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# /usr/lib/python3/dist-packages/pint/quantity.py:1377: UnitStrippedWarning: The unit of the quantity is stripped.
#   warnings.warn("The unit of the quantity is stripped.", UnitStrippedWarning)
# 787.1955830790321 nanometer
# 396.9885739176378 nanometer
# 1177.4870129438195 nanometer
# <img src="data:image/png;base64,..." width="900">
# <img src="data:image/png;base64,..." width="900">
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/slayoo/devel/ripening/Activ_Deactiv.ipynb in <module>()
#      14 plt.show()
#      15
# ---> 16 plt.savefig(setup.figname_radii)
#
# /usr/lib/python3/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# /usr/lib/python3/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata, **kwargs)
#    2556             file = filename._file
#    2557         else:
# -> 2558             file = PdfFile(filename, metadata=metadata)
#    2559         try:
#    2560             file.newPage(width, height)
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_pdf.py in __init__(self, filename, metadata)
#     431         self.original_file_like = None
#     432         self.tell_base = 0
# --> 433         fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     434         if not opened:
#     435             try:
#
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     390             fh = bz2.BZ2File(fname, flag)
#     391         else:
# --> 392             fh = open(fname, flag, encoding=encoding)
#     393         opened = True
#     394     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pics/sim2_radii.pdf'
